# %% [markdown]
# # Heart Failure Dectection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('heart_failure_clinical_records_dataset.csv')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
features=df.columns
features
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# ## Data Visualization

# %%
lives=df[df['DEATH_EVENT']==0]
deaths=df[df['DEATH_EVENT']==1]
result=np.array([deaths.shape[0],lives.shape[0]])
plt.pie(result,labels=['deaths','live'],autopct='%1.1f%%',shadow=True,explode=[0,0.2])
plt.title("Mortality")
plt.show()

# %%
lives_diabetes=df[(df['DEATH_EVENT']==0) & (df['diabetes']==1)]
deaths_diabetes=df[(df['DEATH_EVENT']==1) & (df['diabetes']==1)]
result=np.array([deaths_diabetes.shape[0],lives_diabetes.shape[0]])
plt.pie(result,labels=['deaths','live'],autopct='%1.1f%%',shadow=True,explode=[0,0.2])
plt.title("Diabetes Mortality")
plt.show()

# %%
lives_smoker=df[(df['DEATH_EVENT']==0) & (df['smoking']==1)]
deaths_smoker=df[(df['DEATH_EVENT']==1) & (df['smoking']==1)]
result=np.array([deaths_smoker.shape[0],lives_smoker.shape[0]])
plt.pie(result,labels=['deaths','live'],autopct='%1.1f%%',shadow=True,explode=[0,0.2])
plt.title("Smoking Mortality")
plt.show()

# %%
lives_anaemia=df[(df['DEATH_EVENT']==0) & (df['anaemia']==1)]
deaths_anaemia=df[(df['DEATH_EVENT']==1) & (df['anaemia']==1)]
result=np.array([deaths_anaemia.shape[0],lives_anaemia.shape[0]])
plt.pie(result,labels=['deaths','live'],autopct='%1.1f%%',shadow=True,explode=[0,0.2])
plt.title("Anaemia Mortality")
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.catplot(df,x='DEATH_EVENT',y='creatinine_phosphokinase')

# %%
sns.catplot(df,x='DEATH_EVENT',y='age')

# %%
# plt.subplots(figsize=(20,10))
sns.catplot(df,x='smoking',y='age')

# %%
plt.subplots(figsize=(20,10))
sns.distplot(df['creatinine_phosphokinase'])
# Out:
# <ipython-input-129-730460e0d346>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['creatinine_phosphokinase'])
# <Axes: xlabel='creatinine_phosphokinase', ylabel='Density'>

# %%
plt.subplots(figsize=(20,10))
sns.distplot(df['serum_creatinine'])
# Out:
# <ipython-input-130-8b168811f9f7>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['serum_creatinine'])
# <Axes: xlabel='serum_creatinine', ylabel='Density'>

# %%
plt.subplots(figsize=(20,10))
sns.distplot(df['serum_sodium'])
# Out:
# <ipython-input-131-4e9b401fa941>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['serum_sodium'])
# <Axes: xlabel='serum_sodium', ylabel='Density'>

# %%
plt.subplots(figsize=(20,10))
sns.distplot(df['age'])
# Out:
# <ipython-input-132-b0d7cd451436>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ## Over Sampling Data

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(random_state=42)


lives.shape
deaths.shape
# Out:
# (96, 13)

# %%
X = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']

X_resampled, y_resampled = os.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# DEATH_EVENT
# 1    203
# 0    203
# Name: count, dtype: int64

# %% [markdown]
# ## Model Selection , Prepocessing and Performance Metrics

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler,MinMaxScaler
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42,stratify=y_resampled)

# %%
from sklearn.pipeline import make_pipeline
model=make_pipeline(MinMaxScaler(),LogisticRegression())
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
acc=accuracy_score(y_test,y_pred)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.76        41
#            1       0.79      0.63      0.70        41
#
#     accuracy                           0.73        82
#    macro avg       0.74      0.73      0.73        82
# weighted avg       0.74      0.73      0.73        82
#
# [[34  7]
#  [15 26]]
# 0.7317073170731707

# %%
from sklearn.ensemble import RandomForestClassifier
model2=make_pipeline(MinMaxScaler(),RandomForestClassifier(random_state=42))
model2.fit(X_train,y_train)
y_pred2=model2.predict(X_test)
acc2=accuracy_score(y_test,y_pred2)
print(classification_report(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(acc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        41
#            1       0.89      0.95      0.92        41
#
#     accuracy                           0.91        82
#    macro avg       0.92      0.91      0.91        82
# weighted avg       0.92      0.91      0.91        82
#
# [[36  5]
#  [ 2 39]]
# 0.9146341463414634

# %%
from sklearn.ensemble import GradientBoostingClassifier
model3=make_pipeline(MinMaxScaler(),GradientBoostingClassifier(random_state=42))
model3.fit(X_train,y_train)
y_pred3=model3.predict(X_test)
acc3=accuracy_score(y_test,y_pred3)
print(classification_report(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(acc3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        41
#            1       0.86      0.88      0.87        41
#
#     accuracy                           0.87        82
#    macro avg       0.87      0.87      0.87        82
# weighted avg       0.87      0.87      0.87        82
#
# [[35  6]
#  [ 5 36]]
# 0.8658536585365854

# %%
from sklearn.neighbors import KNeighborsClassifier
model4=make_pipeline(MinMaxScaler(),KNeighborsClassifier())
model4.fit(X_train,y_train)
y_pred4=model4.predict(X_test)
acc4=accuracy_score(y_test,y_pred4)
print(classification_report(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
print(acc4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68        41
#            1       0.69      0.44      0.54        41
#
#     accuracy                           0.62        82
#    macro avg       0.64      0.62      0.61        82
# weighted avg       0.64      0.62      0.61        82
#
# [[33  8]
#  [23 18]]
# 0.6219512195121951

# %% [markdown]
# # The Conclusion

# %% [markdown]
# The **Random Forest Classifier** is the optimal model for this dataset as the accuracy is the highest and the recall score is the best which would help the model prevent false negatives which is very crucial for this type of mortality predictor or expectency predictor
